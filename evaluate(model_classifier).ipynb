# %% [markdown]
# <a href="https://colab.research.google.com/github/harshit37/MS333_Ciao_Bella/blob/master/evaluate(model_classifier).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fastai.vision import *
from fastai.metrics import accuracy

# %%
import pickle
import shutil

shutil.copy("/content/drive/My Drive/sedan_suv.pkl","/content")
shutil.copy("/content/drive/My Drive/one-epoch.pth","/content")
# Out:
# '/content/one-epoch.pth'

# %%
learner=load_learner("/content/pura_model","/content/sedan_suv.pkl")

# %%
path =  "/content/drive/My Drive/SIH/cropped/classify/Sedan_data/"
img = open_image(get_image_files(path)[1])
img.show()

# %%
pred_class,pred_idx,outputs = learner.predict(img)
print(pred_class)
print(pred_idx)
print(outputs)
# Out:
# Sedan_data
# tensor(1)
# tensor([3.8101e-02, 9.6159e-01, 3.0816e-04])

# %%
path =  "/content/drive/My Drive/SIH/cropped/classify/SUV_data/"
img = open_image(get_image_files(path)[3])
img.show()

# %%
pred_class,pred_idx,outputs = learner.predict(img)
print(pred_class)
print(pred_idx)
print(outputs)
# Out:
# SUV_data
# tensor(0)
# tensor([0.8051, 0.1932, 0.0017])
